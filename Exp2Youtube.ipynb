# %%
from googleapiclient.discovery import build

# api_key = 'YOUR_API_KEY'  # Replace with your actual API key
api_key = 'AIzaSyBoThyRMSWTxiY5sHjdzo2zszkE1fgJPDs'


def get_comments(video_id):
    youtube = build('youtube', 'v3', developerKey=api_key)
    
    next_page_token = None

    while True:
        response = youtube.commentThreads().list(
            part='snippet,replies',
            videoId=video_id,
            maxResults=5,  # Limit results to make it faster (optional)
            pageToken=next_page_token
        ).execute()

        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            print(f"Comment: {comment}")

            replies = item.get('replies', {}).get('comments', [])
            if replies:
                for reply in replies:
                    print(f"↳ Reply: {reply['snippet']['textDisplay']}")
            else:
                print("↳ No replies.")
            print()

        # Check if there is a next page
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

# Example usage
get_comments("LLAZUTbc97I")
# Out:
# Comment: Direct and Short. Wonderful Video. Thank you so much
# ↳ Reply: Thank so much
#
# Comment: You got me subbed right away! So simple yet very direct!
# ↳ Reply: Thank you so much 💓
#
# Comment: thank you soo much. without wasting time and point to point video ❤
# ↳ Reply: Thank for those highlights. Will try to follow the same in the next videos 📹
#
# Comment: Very good 😊
# ↳ Reply: Thank you! Cheers!
#
# Comment: <a href="https://www.youtube.com/watch?v=LLAZUTbc97I&amp;t=43">0:43</a> test
# ↳ No replies.
#
# Comment: This was a clear explanation, easy to follow and accurate. Thank you
# ↳ Reply: Your welcome 🙏
#
# Comment: Hi from Athens, Greece. My question is that in Kodi Youtube addon settings there are  in the API line 3 codes to fullfil: first is: API Key second is: Project API id and third is: Secret API. You showed in this video only how to find the first API Key. What about the other 2 codes? Are they left blank?
# ...

# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyBoThyRMSWTxiY5sHjdzo2zszkE1fgJPDs'

def get_comments(video_id):
    yt = build('youtube', 'v3', developerKey=api_key)
    token = None

    while True:
        res = yt.commentThreads().list(part='snippet,replies', videoId=video_id, pageToken=token).execute()
        for i in res['items']:
            print("Comment:", i['snippet']['topLevelComment']['snippet']['textDisplay'])
            for r in i.get('replies', {}).get('comments', []):
                print("↳", r['snippet']['textDisplay'])
        token = res.get('nextPageToken')
        if not token:
            break

get_comments("LLAZUTbc97I")
# Out:
# Comment: Direct and Short. Wonderful Video. Thank you so much
# ↳ Thank so much
# Comment: You got me subbed right away! So simple yet very direct!
# ↳ Thank you so much 💓
# Comment: thank you soo much. without wasting time and point to point video ❤
# ↳ Thank for those highlights. Will try to follow the same in the next videos 📹
# Comment: Very good 😊
# ↳ Thank you! Cheers!
# Comment: <a href="https://www.youtube.com/watch?v=LLAZUTbc97I&amp;t=43">0:43</a> test
# Comment: This was a clear explanation, easy to follow and accurate. Thank you
# ↳ Your welcome 🙏
# Comment: Hi from Athens, Greece. My question is that in Kodi Youtube addon settings there are  in the API line 3 codes to fullfil: first is: API Key second is: Project API id and third is: Secret API. You showed in this video only how to find the first API Key. What about the other 2 codes? Are they left blank?
# ...
