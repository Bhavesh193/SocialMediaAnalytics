# %%
import pandas as pd
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")

# Updated file path
file_path = r"C:\Users\hp\Desktop\BaveshSma\google.xlsx"

try:
    # Load the Excel file into a DataFrame
    df = pd.read_excel(file_path)
    logging.info("Excel file loaded successfully.")

    # Display the first few rows of the original data
    print("\n=== Original Data (First 5 Rows) ===")
    print(df.head())

    # Step 1: Remove duplicate rows
    df_cleaned = df.drop_duplicates()
    logging.info("Duplicate rows removed.")

    # Step 2: Handle missing values (Automatically fill with 'Unknown')
    df_cleaned = df_cleaned.fillna("Unknown")
    logging.info("Filled missing values with 'Unknown'.")

    # Step 3: Standardize column names
    df_cleaned.columns = df_cleaned.columns.str.lower().str.replace(' ', '_', regex=True)
    logging.info("Column names standardized.")

    # Display the cleaned data on screen
    print("\n=== Cleaned Data (First 5 Rows) ===")
    print(df_cleaned.head())

except Exception as e:
    logging.error(f"An error occurred: {e}")
# Out:
# INFO: Excel file loaded successfully.
# INFO: Duplicate rows removed.
# INFO: Filled missing values with 'Unknown'.
# INFO: Column names standardized.
# === Original Data (First 5 Rows) ===
#                                           NBa7we src           d4r55  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjV2P...        Sia Sahu
# 1  https://lh3.googleusercontent.com/a-/ALV-UjW3C...   Girish Kamble
# 2  https://lh3.googleusercontent.com/a-/ALV-UjXdU...   Deepak Kapure
# 3  https://lh3.googleusercontent.com/a-/ALV-UjURT...       skcharagi
# 4  https://lh3.googleusercontent.com/a-/ALV-UjUv6...  Alpha Predator
#
#                                       RfnDt        rsqaWe  \
# 0                                 7 reviews  3 months ago
# 1    Local Guide · 164 reviews · 857 photos   3 years ago
# 2  Local Guide · 323 reviews · 1,729 photos   4 years ago
# 3       Local Guide · 46 reviews · 3 photos    a week ago
# 4    Local Guide · 150 reviews · 974 photos   5 years ago
#
#                                               wiI7pd dSlJg Hzvxle  pkWtMe  \
# 0  Everytime I am visiting it I observe carelessn...        Like     3.0
# 1  I got this hospital as my Vaccination Center f...        Like    11.0
# 2  Good hospital. A neat and clean hospital with ...        Like    10.0
# 3  Two ex chairmen died young.\nTreatment delayed...         NaN     NaN
# 4  Huge infrastructure and a quite clean hospital...        Like     3.0
#
#   dSlJg 2  znYl0 znYl0 2
# 0         Share     NaN
# 1         Share     NaN
# 2         Share     NaN
# 3         Share    Like
# 4         Share     NaN
#
# === Cleaned Data (First 5 Rows) ===
#                                           nba7we_src           d4r55  \
# 0  https://lh3.googleusercontent.com/a-/ALV-UjV2P...        Sia Sahu
# 1  https://lh3.googleusercontent.com/a-/ALV-UjW3C...   Girish Kamble
# 2  https://lh3.googleusercontent.com/a-/ALV-UjXdU...   Deepak Kapure
# 3  https://lh3.googleusercontent.com/a-/ALV-UjURT...       skcharagi
# 4  https://lh3.googleusercontent.com/a-/ALV-UjUv6...  Alpha Predator
#
#                                       rfndt        rsqawe  \
# 0                                 7 reviews  3 months ago
# 1    Local Guide · 164 reviews · 857 photos   3 years ago
# 2  Local Guide · 323 reviews · 1,729 photos   4 years ago
# 3       Local Guide · 46 reviews · 3 photos    a week ago
# 4    Local Guide · 150 reviews · 974 photos   5 years ago
#
#                                               wii7pd dsljg   hzvxle   pkwtme  \
# 0  Everytime I am visiting it I observe carelessn...          Like      3.0
# 1  I got this hospital as my Vaccination Center f...          Like     11.0
# 2  Good hospital. A neat and clean hospital with ...          Like     10.0
# 3  Two ex chairmen died young.\nTreatment delayed...       Unknown  Unknown
# 4  Huge infrastructure and a quite clean hospital...          Like      3.0
#
#   dsljg_2  znyl0  znyl0_2
# 0         Share  Unknown
# 1         Share  Unknown
# 2         Share  Unknown
# 3         Share     Like
# 4         Share  Unknown

# %%
import pandas as pd

# Load the Excel file
file_path = "./social_media_data_50.xlsx"  # Replace with your actual path
df = pd.read_excel(file_path)

print("\n--- Original Data ---")
print(df.head())

# Step 1: Remove duplicates
df = df.drop_duplicates()

# Step 2: Fill missing values
df = df.fillna("Unknown")

# Step 3: Standardize column names
df.columns = df.columns.str.lower().str.replace(" ", "_")

print("\n--- Cleaned Data ---")
print(df.head())

# Save cleaned data
# df.to_excel("cleaned_social_media_data.xlsx", index=False)
print(df.head)
# Out:
# --- Original Data ---
#   Username                               Post  Likes  Comments   Platform
# 0   user_8  Anyone up for a coding challenge?  945.0      98.0   Facebook
# 1   user_2            Feeling grateful today.  877.0      83.0  Instagram
# 2  user_17  Anyone up for a coding challenge?  845.0      19.0   LinkedIn
# 3  user_14                                NaN  546.0      51.0  Instagram
# 4   user_3       Can't believe this happened!   43.0      70.0   LinkedIn
#
# --- Cleaned Data ---
#   username                               post  likes comments   platform
# 0   user_8  Anyone up for a coding challenge?  945.0     98.0   Facebook
# 1   user_2            Feeling grateful today.  877.0     83.0  Instagram
# 2  user_17  Anyone up for a coding challenge?  845.0     19.0   LinkedIn
# 3  user_14                            Unknown  546.0     51.0  Instagram
# 4   user_3       Can't believe this happened!   43.0     70.0   LinkedIn
# <bound method NDFrame.head of    username                               post    likes comments   platform
# 0    user_8  Anyone up for a coding challenge?    945.0     98.0   Facebook
# 1    user_2            Feeling grateful today.    877.0     83.0  Instagram
# 2   user_17  Anyone up for a coding challenge?    845.0     19.0   LinkedIn
# 3   user_14                            Unknown    546.0     51.0  Instagram
# 4    user_3       Can't believe this happened!     43.0     70.0   LinkedIn
# 5   user_11                Weekend vibes only.    535.0     45.0  Instagram
# 6    user_6                Weekend vibes only.    835.0     27.0    YouTube
# 7    user_1          Just launched my website!    484.0     21.0    Twitter
# 8    user_5             New blog post is live!  Unknown     96.0    YouTube
# 9   user_10                            Unknown    841.0     49.0   LinkedIn
# 10   user_9             New blog post is live!    116.0     28.0    YouTube
# 11  user_12            Feeling grateful today.    333.0  Unknown  Instagram
# 12  user_10          Just launched my website!    254.0     89.0  Instagram
# 13  user_10                            Unknown    176.0     36.0  Instagram
# 14  user_18                            Unknown    753.0     97.0  Instagram
# 15  user_14  Anyone up for a coding challenge?    920.0     19.0  Instagram
# 16  user_20            Learning Python is fun!  Unknown     14.0    YouTube
# 17  user_11             New blog post is live!    958.0     47.0    Twitter
# 18   user_2  Anyone up for a coding challenge?    646.0     81.0    Twitter
# 19  user_16            Feeling grateful today.    468.0     86.0  Instagram
# 20   user_2             New blog post is live!    895.0     29.0  Instagram
# 21  user_11          Just launched my website!    511.0     83.0  Instagram
# 22  user_17            Feeling grateful today.    397.0     63.0   Facebook
# 23  user_12            Feeling grateful today.    404.0     78.0   LinkedIn
# 24  user_10       Can't believe this happened!    500.0     83.0    YouTube
# 25  user_20            Feeling grateful today.    770.0     27.0   Facebook
# 26  user_14          Just launched my website!    611.0     80.0   LinkedIn
# 27  user_16            Check out my new video!  Unknown    100.0   Facebook
# 28   user_6            Check out my new video!    303.0     12.0  Instagram
# 29   user_2                Weekend vibes only.     66.0     34.0    Twitter
# 30  user_19                            Unknown    104.0     36.0   Facebook
# 31   user_2                            Unknown     87.0     47.0    YouTube
# 32   user_1            Feeling grateful today.    829.0     88.0  Instagram
# 33  user_16            Feeling grateful today.     88.0     34.0   Facebook
# 34   user_1                Weekend vibes only.    445.0     83.0    YouTube
# 35   user_4            Feeling grateful today.    374.0    100.0   Facebook
# 36  user_11                Weekend vibes only.    624.0      7.0   LinkedIn
# 37   user_1            Feeling grateful today.     78.0     63.0  Instagram
# 38   user_6            Check out my new video!  Unknown     74.0    YouTube
# 39  user_16            Check out my new video!    879.0     16.0   LinkedIn
# 40   user_4          Just launched my website!    852.0     86.0    YouTube
# 41  user_16             New blog post is live!    719.0     10.0   LinkedIn
# 42   user_1          Just launched my website!    833.0     63.0   LinkedIn
# 43   user_9            Feeling grateful today.    646.0     35.0  Instagram
# 44  user_14             New blog post is live!    872.0     78.0    YouTube
# 45  user_13              Amazing sunset today.    279.0     92.0   LinkedIn
# 46   user_7  Anyone up for a coding challenge?    920.0     43.0    Twitter
# 47  user_11            Learning Python is fun!    112.0     14.0   Facebook
# 48   user_2            Learning Python is fun!     77.0     26.0    YouTube
# 49   user_8            Learning Python is fun!    211.0     85.0   LinkedIn>

# %%
import pandas as pd

# Load dataset
df = pd.read_excel("./social_media_data_50.xlsx")

# Remove duplicates
df = df.drop_duplicates()

# Standardize column names
df.columns = df.columns.str.lower().str.replace(" ", "_")

# Fill missing values meaningfully
df["username"] = df["username"].fillna("anonymous_user")
df["post"] = df["post"].fillna("No content provided")
df["likes"] = df["likes"].fillna(0).astype(int)
df["comments"] = df["comments"].fillna(0).astype(int)
df["platform"] = df["platform"].fillna("Unknown platform")

# Show cleaned data
print("\n--- Cleaned Data Preview ---")
print(df.head())

# Save cleaned data
df.to_excel("cleaned_social_media_data_50.xlsx", index=False)
# Out:
# --- Cleaned Data Preview ---
#          username                               post  likes  comments  \
# 0          user_8  Anyone up for a coding challenge?    945        98
# 1          user_2            Feeling grateful today.      0        83
# 2  anonymous_user  Anyone up for a coding challenge?    845        19
# 3         user_14                No content provided    546        51
# 4          user_3       Can't believe this happened!     43        70
#
#            platform
# 0          Facebook
# 1         Instagram
# 2  Unknown platform
# 3         Instagram
# 4          LinkedIn
